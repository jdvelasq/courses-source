# %% [markdown]
# Caso de estudio: Gráficos con varias series de tiempo
# ===

# %%
import numpy as np
import pandas as pd

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()
data = data.dropna()
data.head()
# Out:
#                    A         B         C         D
# 2016-01-07 -2.452745  1.051882  0.869730  2.501669
# 2016-01-08 -2.947736  1.154990  0.861469  2.497520
# 2016-01-09 -3.321732  1.161639  1.080810  2.444158
# 2016-01-10 -3.469003  1.309605  1.126083  2.298421
# 2016-01-11 -3.808518  1.460720  0.890171  2.348546

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
for i in data.columns:
    plt.plot(data.index, data[i], label=i)
plt.legend()

# %%
colors = {
    "A": "tab:blue",
    "B": "tab:orange",
    "C": "tab:green",
    "D": "tab:red",
}

linestyles = {
    "A": "-",
    "B": "--",
    "C": "-.",
    "D": ":",
}

linewidhts = {
    "A": 1,
    "B": 2,
    "C": 3,
    "D": 4,
}

plt.figure(figsize=(7,4))
for i in data.columns:
    plt.plot(
        data.index,
        data[i],
        label=i,
        color=colors[i],
        linestyle=linestyles[i],
        linewidth=linewidhts[i],
    )

plt.legend()
