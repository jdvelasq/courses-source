# %% [markdown]
# Caso de estudio: Personalización de un boxplot
# ===

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

data = pd.DataFrame(D, columns=["A", "B", "C"])
data.head()
# Out:
#           A         B         C
# 0  4.664483  5.715279  2.068250
# 1  2.989520  5.621336  3.099893
# 2  3.331889  5.108549  4.005364
# 3  2.781750  5.433026  5.503797
# 4  1.793668  6.028274  4.285788

# %%
fig, ax = plt.subplots(figsize=(8, 4))
VP = ax.boxplot(data)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
VP = ax.boxplot(
    data,
    widths=0.9,
    patch_artist=True,
    showmeans=False,
    showfliers=False,
    medianprops={"color": "white", "linewidth": 0.5},
    boxprops={"facecolor": "C0", "edgecolor": "white", "linewidth": 0.5},
    whiskerprops={"color": "C0", "linewidth": 1.5},
    capprops={"color": "C0", "linewidth": 1.5},
)

ax.set(
    xlim=(0, 4),
    xticks=np.arange(1, 4),
    ylim=(0, 8),
    yticks=np.arange(1, 8),
)

plt.show()
